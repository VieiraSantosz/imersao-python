# %%
# bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import mplfinance as mpf
import yfinance as yf

# %%
# pela a biblioteca da yfinance, pegar a bolsa de valores da Petrobras no ano de 2023
df_petrobas = yf.download('PETR4.SA', start='2023-01-01', end='2023-12-31')

display(df_petrobas)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2023-01-02  23.540001  23.809999  22.799999  22.920000  17.709478   78424700
# 2023-01-03  22.940001  23.100000  22.129999  22.340000  17.261332   96750300
# 2023-01-04  21.959999  23.590000  21.830000  23.049999  17.809923  129504000
# 2023-01-05  23.340000  24.040001  23.150000  23.879999  18.451235   73886000
# 2023-01-06  23.940001  24.320000  23.549999  23.740000  18.343063   51851500
# ...               ...        ...        ...        ...        ...        ...
# 2023-12-21  36.669998  36.680000  36.070000  36.389999  36.389999   30511900
# 2023-12-22  36.500000  36.799999  36.369999  36.740002  36.740002   31234700
# 2023-12-26  36.860001  37.369999  36.830002  37.330002  37.330002   23466800
# 2023-12-27  37.320000  37.430000  37.130001  37.360001  37.360001   19588500
# ...

# %%
# renomear todas as colunas do DataFrame
df_petrobas.columns = ['Abertura', 'Maximo', 'Minimo', 'Fechamento', 'Fech_Ajust', 'Volume']

display(df_petrobas.columns)
# Out:
# Index(['Abertura', 'Maximo', 'Minimo', 'Fechamento', 'Fech_Ajust', 'Volume'], dtype='object')

# %%
# renomear a parte do Date para Data
df_petrobas = df_petrobas.rename_axis('Data')

display(df_petrobas)
# Out:
#              Abertura     Maximo     Minimo  Fechamento  Fech_Ajust     Volume
# Data
# 2023-01-02  23.540001  23.809999  22.799999   22.920000   17.709478   78424700
# 2023-01-03  22.940001  23.100000  22.129999   22.340000   17.261332   96750300
# 2023-01-04  21.959999  23.590000  21.830000   23.049999   17.809923  129504000
# 2023-01-05  23.340000  24.040001  23.150000   23.879999   18.451235   73886000
# 2023-01-06  23.940001  24.320000  23.549999   23.740000   18.343063   51851500
# ...               ...        ...        ...         ...         ...        ...
# 2023-12-21  36.669998  36.680000  36.070000   36.389999   36.389999   30511900
# 2023-12-22  36.500000  36.799999  36.369999   36.740002   36.740002   31234700
# 2023-12-26  36.860001  37.369999  36.830002   37.330002   37.330002   23466800
# 2023-12-27  37.320000  37.430000  37.130001   37.360001   37.360001   19588500
# 2023-12-28  37.230000  37.360001  37.040001   37.240002   37.240002   21421900
#
# ...

# %%
# criação de um gráfico com a variação dos preços por data
df_petrobas['Fechamento'].plot(figsize=[12, 8])

plt.title('Variação do Preço por Data', fontsize=16)

plt.legend(['Fechamento'])

# %%
# criação de um Candlestick das ações da Petrobras
dados = yf.download('PETR4.SA', start='2023-01-01', end='2023-12-31')

mpf.plot(dados.head(60), type='candle', figsize=(16, 8),
        volume=True, mav=(7, 14), style='yahoo')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
# pela a biblioteca da yfinance, pegar a bolsa de valores da Apple no ano de 2020
df_apple = yf.download('AAPL', start='2020-01-01', end='2020-12-31')

display(df_apple)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02   74.059998   75.150002   73.797501   75.087502   73.059425
# 2020-01-03   74.287498   75.144997   74.125000   74.357498   72.349121
# 2020-01-06   73.447502   74.989998   73.187500   74.949997   72.925636
# 2020-01-07   74.959999   75.224998   74.370003   74.597504   72.582664
# 2020-01-08   74.290001   76.110001   74.290001   75.797501   73.750237
# ...                ...         ...         ...         ...         ...
# 2020-12-23  132.160004  132.429993  130.779999  130.960007  128.523270
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  129.514450
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  134.146622
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  132.360519
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  131.231918
#
#                Volume
# Date
# ...

# %%
# criação de um Candlestick das ações da Apple
mpf.plot(df_apple.head(60), type='candle', figsize=(16, 8),
        volume=True, mav=(7, 14), style='yahoo')
